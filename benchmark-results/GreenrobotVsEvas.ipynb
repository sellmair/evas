// %%
%use kandy
        import org.jetbrains.kotlinx.dataframe.api.columnOf
        import org.jetbrains.kotlinx.dataframe.api.dataFrameOf
        import org.jetbrains.letsPlot.Geom

val names = listOf("evas", "greenrobot")
val ops = listOf(10698.541 * 1000, 16753.840 * 1000)


plot {
    layout.title = "Single Threaded Event Emission"
    layout.subtitle = "Higher is better"
    layout.size = 800 to 300
    
    barsH {
        y(names) { axis.name = "" }
        x(ops) { axis.name = "Events/s"}
        alpha = 0.75



        fillColor(names) {
            scale = categorical(
                "evas" to Color.LIGHT_BLUE,
                "greenrobot" to Color.LIGHT_GREEN
            )
            legend.type = LegendType.None
        }
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='800' height='300' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.2.0/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;z0uPkS&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Single Threaded Event Emission&quot;,
// &quot;subtitle&quot;:&quot;Higher is better&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:800.0,
// &quot;height&quot;:300.0
// },
// ...

// %%
%use kandy
import org.jetbrains.kotlinx.dataframe.api.columnOf
import org.jetbrains.kotlinx.dataframe.api.dataFrameOf
import org.jetbrains.kotlinx.kandy.ir.scale.PositionalScale
import org.jetbrains.letsPlot.Geom
import org.jetbrains.letsPlot.core.spec.back.transform.bistro.util.scale
import org.jetbrains.letsPlot.scale.scaleXLog10
import org.jetbrains.letsPlot.scale.scaleYLog10

val names = listOf("evas", "greenrobot")
val ops = listOf(1246.040, 5.588).map { it * 1000 * 8 }


plot {
    layout.title = "Multi Threaded (8) Event Emission"
    layout.subtitle = "Higher is better"
    layout.size = 800 to 300

    
    barsH {
        y(names) { axis.name = "" }
        x(ops) { 
            axis.name = "Events/s"
            scale = continuous(transform = Transformation.LOG10)
        }
        alpha = 0.75
        
        fillColor(names) {
            scale = categorical(
                "evas" to Color.LIGHT_BLUE,
                "greenrobot" to Color.LIGHT_GREEN
            )
            legend.type = LegendType.None
        }
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='800' height='300' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.2.0/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;dISNIV&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Multi Threaded (8) Event Emission&quot;,
// &quot;subtitle&quot;:&quot;Higher is better&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:800.0,
// &quot;height&quot;:300.0
// },
// ...

// %%
%use kandy
        import org.jetbrains.kotlinx.dataframe.api.columnOf
        import org.jetbrains.kotlinx.dataframe.api.dataFrameOf
        import org.jetbrains.kotlinx.kandy.ir.scale.PositionalScale
        import org.jetbrains.letsPlot.Geom
        import org.jetbrains.letsPlot.core.spec.back.transform.bistro.util.scale
        import org.jetbrains.letsPlot.scale.scaleXLog10
        import org.jetbrains.letsPlot.scale.scaleYLog10

val names = listOf("evas", "greenrobot")
val us = listOf(23.075, 88.689)


plot {
    layout.title = "Startup Time"
    layout.subtitle = "Lower is better"
    layout.size = 300 to 300

    val names = listOf("evas", "greenrobot")
    val min = listOf(22.042, 1423.000)
    val max = listOf(49.916, 1779)
    
    errorBars {
        this.y.axis.name = "microsecond"
        x(names) { axis.name = "" }
        yMin(min)
        yMax(max)
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='300' height='300' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.2.0/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;rCTafB&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Startup Time&quot;,
// &quot;subtitle&quot;:&quot;Lower is better&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:300.0,
// &quot;height&quot;:300.0
// },
// ...
